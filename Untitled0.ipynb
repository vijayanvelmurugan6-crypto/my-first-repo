# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayanvelmurugan6-crypto/my-first-repo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Github ! ")
# Out:
# Hello Github !
